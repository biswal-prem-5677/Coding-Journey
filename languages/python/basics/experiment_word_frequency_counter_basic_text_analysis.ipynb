# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/languages/python/basics/experiment_word_frequency_counter_basic_text_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter

text = input("Enter text: ")

words = text.lower().split()

count = Counter(words)

for word, freq in count.items():
    print(word, ":", freq)
# Out:
# Enter text: poiuy poiuy poiuy poiuy
# poiuy : 4
