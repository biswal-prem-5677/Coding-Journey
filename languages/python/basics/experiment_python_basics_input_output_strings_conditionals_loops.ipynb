# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/languages/python/basics/experiment_python_basics_input_output_strings_conditionals_loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Functions

# %% [markdown]
# docs.python.org
#
# docs.python.org/3/library/functions.html
#
# docs.python.org/3/library/functions.html#print
#
#
# print(*objects, sep='', end='\n', file=sys.stdout, flush=False)

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name=input("What's Your Name? ")
print("Hello, ",name)
# Out:
# What's Your Name? PREM
# Hello,  PREM

# %%
name=input("What's Your Name?")
print("Hello,", name)
# Out:
# What's Your Name?Prem
# Hello, Prem

# %%
name=input("What's Your Name?")
print("Hello, ", + name)
# Out:
# What's Your Name?Prem
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-703653884.py in <cell line: 0>()
#       1 name=input("What's Your Name?")
# ----> 2 print("Hello, ", + name)
#
# TypeError: bad operand type for unary +: 'str'

# %%
name=input("What's Your Name?")
print("Hello, ")
print(name)
# Out:
# What's Your Name?Prem
# Hello,
# Prem

# %% [markdown]
# Posistional parameters

# %%
name=input("What's Your Name?")
print("Hello, ", end="")
print(name)
# Out:
# What's Your Name?Prem
# Hello, Prem

# %%
name=input("What's Your Name?")
print("Hello, ", end="????")                    #named parameters
print(name)
# Out:
# What's Your Name?PRem
# Hello, ????PRem

# %%
name=input("What's Your Name?")
print("Hello,", name,sep="???")             #named parameters
# Out:
# What's Your Name?Prem
# Hello,???Prem

# %%
print("Hello, "Friend"")
# Out:
#   File "/tmp/ipython-input-2497879096.py", line 1
#     print("Hello, "Friend"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('Hello, "Friend"')
# Out:
# Hello, "Friend"

# %%
print("Hello, \"Friend\"")             #Escape sequences
# Out:
# Hello, "Friend"

# %% [markdown]
# format string or fstring
# that tells python to format stuff in a string in a special way

# %%
name=input("What's Your Name? ")
print("Hello, {name}")
# Out:
# What's Your Name? Prem
# Hello, {name}

# %%
name=input("What's Your Name? ")
print(f"Hello, {name}")
# Out:
# What's Your Name? Prem
# Hello, Prem

# %% [markdown]
# Strings
#
# docs.python.org/3/library/functions.html#string-methods

# %%
name=input("What's Your Name? ")
print(f"Hello, {name}")
# Out:
# What's Your Name?                       PREM
# Hello,                       PREM

# %%
name=input("What's Your Name? ")
#Removes whitespaces from string
name=name.strip()
print(f"Hello, {name}")
# Out:
# What's Your Name?                 Prem
# Hello, Prem

# %%
name=input("What's Your Name? ")

#Removes whitespaces from string
name=name.strip()

#Capitalizes user's name
name=name.capitalize()      #name=name.title()     does the same but better

print(f"Hello, {name}")
# Out:
# What's Your Name? prem
# Hello, Prem

# %%
name=input("What's Your Name? ")

#Removes whitespaces from string but only from left and right, not inbetween
name=name.strip()

#Capitalizes user's name
name=name.capitalize()      #name=name.title()     does the samebut better

print(f"Hello, {name}")
# Out:
# What's Your Name?               prem     biswal
# Hello, Prem     biswal

# %%
name=input("What's Your Name? ")

#Removes whitespaces from string
name=name.strip()

#Capitalizes user's name
name=name.title()      #capitalizes first letter of every word

print(f"Hello, {name}")
# Out:
# What's Your Name?          prem      biswal
# Hello, Prem      Biswal

# %%
name=input("What's Your Name? ")

#Capitalizes user's name
name=name.title()

#Removes whitespaces from string
name=name.strip()

print(f"Hello, {name}")
# Out:
# What's Your Name?               prem                    biswal
# Hello, Prem                    Biswal

# %%
name=input("What's Your Name? ")

#Removes whitespaces from string and Capitalizes user's name
name=name.strip().title()

print(f"Hello, {name}")
# Out:
# What's Your Name?            prem biswal
# Hello, Prem Biswal

# %%
name=input("What's Your Name? ")

#Removes whitespaces from string and Capitalizes user's name
name=name.strip().title()

print(f"Hello, {name}")
# Out:
# What's Your Name?                      prem            biswal
# Hello, Prem            Biswal

# %%
name=input("What's Your Name? ").strip().title()
print(f"Hello, {name}")
# Out:
# What's Your Name?             prem               biswal
# Hello, Prem               Biswal

# %%
name=input("What's Your Name? ").strip().title()

# Splits name into first name and last name
first, second = name.split(" ")

print(f"Hello, {first}")
# Out:
# What's Your Name? prem biswal
# Hello, Prem

# %%
name=input("What's Your Name? ").strip().title()

# Splits name into first name and last name
first, second = name.split(" ")

print(f"Hello, {first}")
# Out:
# What's Your Name?       prem          biswal
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3256995335.py in <cell line: 0>()
#       2
#       3 # Splits name into first name and last name
# ----> 4 first, second = name.split(" ")
#       5
#       6 print(f"Hello, {first}")
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# too many spaces given in above o/p

# %% [markdown]
# # Calculator

# %%
x=1
y=2
z=x+y
print(z)
# Out:
# 3

# %%
x=input("What's x? ")    #takes input as string as input type is not mentioned
y=input("What's y? ")

z=x+y                #string concatenation
print(z)
# Out:
# What's x? 1
# What's y? 2
# 12

# %%
x=input("What's x? ")    #takes input as string as input type is not mentioned
y=input("What's y? ")

z=int(x)+int(y)
print(z)
# Out:
# What's x? 1
# What's y? 2
# 3

# %%
x=input("What's x? ")    #takes input as string as input type is not mentioned
y=input("What's y? ")

z=int(x)+y
print(z)
# Out:
# What's x? 1
# What's y? 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1760917185.py in <cell line: 0>()
#       2 y=input("What's y? ")
#       3
# ----> 4 z=int(x)+y
#       5 print(z)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x=int(input("What's x? "))
y=int(input("What's y? "))

z=x+y
print(z)
# Out:
# What's x? 1
# What's y? 2
# 3

# %%
x=int(input("What's x? "))
y=int(input("What's y? "))

print(x+y)
# Out:
# What's x? 1
# What's y? 2
# 3

# %%
print(int(input("What's x? ")) + int(input("What's y? ")))
# Out:
# What's x? 1
# What's y? 2
# 3

# %%
print(int(input("What's x? ")) + int(input("What's y? ")))
print(int(input("What's x? ")) - int(input("What's y? ")))
print(int(input("What's x? ")) * int(input("What's y? ")))
print(int(input("What's x? ")) / int(input("What's y? ")))
# Out:
# What's x? 1
# What's y? 2
# 3
# What's x? 4
# What's y? 5
# -1
# What's x? 6
# What's y? 7
# 42
# What's x? 8
# What's y? 9
# 0.8888888888888888

# %%
print(float(input("What's x? ")) + float(input("What's y? ")))
# Out:
# What's x? 3.4
# What's y? 6.1
# 9.5

# %%
print(z=(int(input("What's x? ")) + int(input("What's y? "))))
# Out:
# What's x? 1
# What's y? 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2991868.py in <cell line: 0>()
# ----> 1 print(z=(int(input("What's x? ")) + int(input("What's y? "))))
#
# TypeError: 'z' is an invalid keyword argument for print()

# %%
x=int(input("What's x? "))
y=int(input("What's y? "))

z=float(x+y)
print(z)
# Out:
# What's x? 1
# What's y? 2
# 3.0

# %%
x=float(input("What's x? "))
y=float(input("What's y? "))

z=int(x+y)
print(z)
# Out:
# What's x? 6.1
# What's y? 3.4
# 9

# %% [markdown]
# docs.python.org/3/library/functions.html#round
#
# round(number[, ndigits)

# %%
x=float(input("What's x? "))
y=float(input("What's y? "))

z=round(x+y)
print(z)
# Out:
# What's x? 3.1
# What's y? 5.2
# 8

# %%
x=float(input("What's x? "))
y=float(input("What's y? "))

print(round(x+y))                   # Rounds up to the nearest integer whether up or down
# Out:
# What's x? 3.4
# What's y? 4.5
# 8

# %%
print(round(float(input("What's x? ")) + float(input("What's y? "))))
# Out:
# What's x? 900
# What's y? 1
# 901

# %%
x=float(input("What's x? "))
y=float(input("What's y? "))

z=round(x+y)
print(f"{z:,}")
# Out:
# What's x? 999
# What's y? 1
# 1,000

# %%
x=float(input("What's x? "))
y=float(input("What's y? "))

z=round(x/y)
print(z)
# Out:
# What's x? 2
# What's y? 3
# 1

# %%
x=float(input("What's x? "))
y=float(input("What's y? "))

z=round(x/y,2)           # Rounds off upto a particular decimal place
print(z)
# Out:
# What's x? 2
# What's y? 3
# 0.67

# %%
x=float(input("What's x? "))
y=float(input("What's y? "))

z=x/y
print(f'{z:.2f}')           # Rounds off upto a particular decimal place
# Out:
# What's x? 2
# What's y? 3
# 0.67

# %% [markdown]
# ## Functions

# %% [markdown]
# we can define a function using 'def' keyword

# %%
name=input("What's Your Name? ")
hello()                              # Not defined
print(name)
# Out:
# What's Your Name? Prem
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3021417679.py in <cell line: 0>()
#       1 name=input("What's Your Name? ")
# ----> 2 hello()
#       3 print(name)
#
# NameError: name 'hello' is not defined

# %%
def hello():
  print("Hello")


name=input("What's Your Name? ")
hello()
print(name)
# Out:
# What's Your Name? Prem
# Hello
# Prem

# %%
def hello(to):
  print("Hello", to)                 # 'Name' variable's value is copid to another variable called 'to' when hello function is called


name=input("What's Your Name? ")
hello(name)
# Out:
# What's Your Name? Prem
# Hello Prem

# %%
def hello(to="World!"):                 # Assigned default value "World!" to the parameter variable to
  print("Hello", to)

hello()
name=input("What's Your Name? ")
hello(name)                             # 'Name' variable's value is copid to another variable called 'to' when hello function is called
# Out:
# Hello World!
# What's Your Name? Prem
# Hello Prem

# %%
def main():
  x=float(input("Enter a value"))
  print("x squared is", square(x))

def square(n):
  return n*n

main()
# Out:
# Enter a value4.4
# x squared is 19.360000000000003

# %%
def main():
  x=float(input("Enter a value"))
  print("x squared is", square(x))

def square(n):
  return n**2

main()
# Out:
# Enter a value5
# x squared is 25.0

# %%
def main():
  x=float(input("Enter a value"))
  print("x squared is", square(x))

def square(n):
  return pow(n,2)                # pow is a inbuilt function that takes two parameters as number comma power

main()
# Out:
# Enter a value9
# x squared is 81.0

# %% [markdown]
# # Conditionals

# %%
x=int(input("Enter a number"))
y=int(input("Enter a number"))

if x < y:
  print("x is less than y")
if x > y:
  print("x is greater than y")
if x == y:
  print("x is equal to y")
# Out:
# Enter a number2
# Enter a number3
# x is less than y

# %%
x=int(input("Enter a number"))
y=int(input("Enter a number"))

if x < y:
  print("x is less than y")
elif x > y:
  print("x is greater than y")
else:
  print("x is equal to y")
# Out:
# Enter a number2
# Enter a number5
# x is less than y

# %%
x=int(input("Enter a number"))
y=int(input("Enter a number"))

if x < y or x > y:
  print("x is not equals to y")
else:
  print("x is equal to y")
# Out:
# Enter a number5
# Enter a number2
# x is not equals to y

# %%
x=int(input("Enter a number"))
y=int(input("Enter a number"))

if x != y:
  print("x is not equals to y")
else:
  print("x is equal to y")
# Out:
# Enter a number2
# Enter a number4
# x is not equals to y

# %%
score=int(input("Score: "))

if score >= 90 and score <= 100:
  print("Grade A")
elif score >= 80 and score < 90:
  print("Grade B")
elif score >= 70 and score < 80:
  print("Grade C")
elif score >= 60 and score < 70:
  print("Grade D")
else:
  print("Grade F")
# Out:
# Score: 99
# Grade A

# %%
score=int(input("Score: "))

if 90 <= score <= 100:
  print("Grade A")
elif 80 <= score < 90:
  print("Grade B")
elif 70 <= score < 80:
  print("Grade B")
elif 60 <= score < 70:
  print("Grade B")
else:
  print("Grade F")
# Out:
# Score: 40
# Grade F

# %%
score=int(input("Score: "))

if score >= 90:
  print("Grade A")
elif score >= 80:
  print("Grade B")
elif score >= 70:
  print("Grade B")
elif score >= 60:
  print("Grade B")
else:
  print("Grade F")
# Out:
# Score: 77
# Grade B

# %%
x=int(input("Number: "))

if x % 2 == 0:
  print("even")
else:
  print("odd")
# Out:
# Score: 4
# even

# %%
def main():
  x=int(input("Number: "))
  if is_even(x):
    print("even")
  else:
    print("odd")

def is_even(n):
  if n % 2 == 0:
    return True
  else:
    return False



main()
# Out:
# Number: 4
# even

# %%
def main():
  x=int(input("Number: "))
  if is_even(x):
    print("even")
  else:
    print("odd")

def is_even(n):
  return True if n % 2 == 0 else False

main()
# Out:
# Number: 4
# even

# %%
def main():
  x=int(input("Number: "))
  if is_even(x):
    print("even")
  else:
    print("odd")

def is_even(n):
  return n % 2 == 0             # if does -> True   if not  -> False

main()
# Out:
# Number: 3
# odd

# %%
name=input("What's Your Name? ")

if name == "Harry":
  print("Gryffindor")
elif name == "Hermione":
  print("Gryffindor")
elif name == "Ron":
  print("Gryffindor")
elif name == "Draco":
  print("Slytherin")
else:
    print("Who?")
# Out:
# What's Your Name? Harry
# Gryffindor

# %%
name=input("What's Your Name? ")

if name == "Harry" or name == "Hermione" or name == "Ron":
  print("Gryffindor")
elif name == "Draco":
  print("Slytherin")
else:
    print("Who?")
# Out:
# What's Your Name? Ron
# Gryffindor

# %%
name=input("What's Your Name? ")

if name == "Harry" or "Hermione" or "Ron":
  print("Gryffindor")
elif name == "Draco":
  print("Slytherin")
else:
    print("Who?")
# Out:
# What's Your Name? Ron
# Gryffindor

# %%
name=input("What's Your Name? ")

if name == "Harry" | "Hermione" | "Ron" :
  print("Gryffindor")
elif name == "Draco":
  print("Slytherin")
else:
    print("Who?")
# Out:
# What's Your Name? Ron
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3782230934.py in <cell line: 0>()
#       1 name=input("What's Your Name? ")
#       2
# ----> 3 if name == "Harry" | "Hermione" | "Ron" :
#       4   print("Gryffindor")
#       5 elif name == "Draco":
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'

# %%
name=input("What's Your Name? ")

match name:
  case "Harry":
    print("Gryffindor")
  case "Hermione":
    print("Gryffindor")
  case "Ron":
    print("Gryffindor")
  case "Draco":
    print("Slytherin")
# Out:
# What's Your Name? Harry
# Gryffindor

# %%
name=input("What's Your Name? ")

match name:
  case "Harry":
    print("Gryffindor")
  case "Hermione":
    print("Gryffindor")
  case "Ron":
    print("Gryffindor")
  case "Draco":
    print("Slytherin")
# Out:
# What's Your Name? Prem

# %%
name=input("What's Your Name? ")

match name:
  case "Harry":
    print("Gryffindor")
  case "Hermione":
    print("Gryffindor")
  case "Ron":
    print("Gryffindor")
  case "Draco":
    print("Slytherin")
  case _:
    print("Who?")
# Out:
# What's Your Name? Prem
# Who?

# %%
name=input("What's Your Name? ")

match name:
  case "Harry" | "Hermione" | "Ron":
    print("Gryffindor")
  case "Draco":
    print("Slytherin")
  case _:
    print("Who?")
# Out:
# What's Your Name? Ron
# Gryffindor

# %% [markdown]
# # Loops

# %%
print("Meow")
print("Meow")
print("Meow")
# Out:
# Meow
# Meow
# Meow

# %%
i=3
while i != 0:
  print("Meow")
  i=i-1
# Out:
# Meow
# Meow
# Meow

# %%
i=1
while i <= 3:
  print("Meow")
  i+=1                    #  ++ or --   doesn't work in python
# Out:
# Meow
# Meow
# Meow

# %%
for i in [0,1,2]:        #  using list to update the values like 0 then 1 then 2
  print("Meow")
# Out:
# Meow
# Meow
# Meow

# %%
for i in range(3):        #  using range function to print specific number of times
  print("Meow")
# Out:
# Meow
# Meow
# Meow

# %%
for _ in range(3):        #  not necessary to take i
  print("Meow")
# Out:
# Meow
# Meow
# Meow

# %%
print("meow "*3)
# Out:
# meow meow meow

# %%
print("meow \t"*3)
# Out:
# meow 	meow 	meow

# %%
print("meow \n"*3)
# Out:
# meow
# meow
# meow

# %%
print("meow"*3)
# Out:
# meowmeowmeow

# %%
print("meow"*3, end="")
# Out:
# meowmeowmeow

# %%
print("meow\n"*3, end="")
# Out:
# meow
# meow
# meow

# %%
n=int(input("What's n? "))
if n < 0 :
  n=int(input("What's n? "))
  if n<0:
    n=int(input("What's n? "))
    if n<0:
      n=int(input("What's n? "))
# Out:
# What's n? -1
# What's n? 3

# %%
while True:
  n=int(input("What's n? "))
  if n<0:
    continue
  else:
    break
# Out:
# What's n? -9
# What's n? -6
# What's n? 8

# %%
while True:
  n=int(input("What's n? "))
  if n>0:
    break


for _ in range(n):
  print("Meow")
# Out:
# What's n? 5
# Meow
# Meow
# Meow
# Meow
# Meow

# %%
def main():
  number=get_number()
  meow(number)



def get_number():
  while True:
    n=int(input("What's n? "))
    if n>0:
      break
  return n



def meow(n):
  for _ in range(n):
    print("Meow")


main()
# Out:
# What's n? 5
# Meow
# Meow
# Meow
# Meow
# Meow

# %%
students=["Hermione", "Harry", "Ron"]
print(students[0])
print(students[1])
print(students[2])
# Out:
# Hermione
# Harry
# Ron

# %%
students=["Hermione", "Harry", "Ron"]
for student in students:
  print(student)
# Out:
# Hermione
# Harry
# Ron

# %%
students=["Hermione", "Harry", "Ron"]
for i in range(len(students)):
  print(students[i])
# Out:
# Hermione
# Harry
# Ron

# %%
students=["Hermione", "Harry", "Ron"]
for i in range(len(students)):
  print(i, students[i])               #print with index position
# Out:
# 0 Hermione
# 1 Harry
# 2 Ron

# %%
students=["Hermione", "Harry", "Ron"]
for i in range(len(students)):
  print(i+1, students[i])     #print top 3 students
# Out:
# 1 Hermione
# 2 Harry
# 3 Ron
