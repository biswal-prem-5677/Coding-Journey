# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/languages/python/basics/experiment_python_functions_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.5/349.5 kB 3.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

# %% [markdown]
# Click the 'Choose Files' button to upload your PDF document.

# %%
uploaded = files.upload()

if uploaded:
    # Assuming only one file is uploaded, get its name
    uploaded_filename = next(iter(uploaded))
    print(f"File '{uploaded_filename}' uploaded successfully.")
else:
    print("No file was uploaded.")
# Out:
#      <input type="file" id="files-3261bed7-cd6b-4733-ae21-d11c6a346d5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3261bed7-cd6b-4733-ae21-d11c6a346d5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pypdf

def read_pdf(pdf_path):
    """
    Reads a PDF file and returns its text content.

    Args:
        pdf_path (str): The path to the PDF file.

    Returns:
        str: The extracted text content from the PDF.
    """
    text = ""
    try:
        with open(pdf_path, 'rb') as file:
            reader = pypdf.PdfReader(file)
            for page_num in range(len(reader.pages)):
                text += reader.pages[page_num].extract_text() or ""
    except Exception as e:
        text = f"Error reading PDF: {e}"
    return text

# %%
pdf_file_path = uploaded_filename

# Call the read_pdf function
extracted_text = read_pdf(pdf_file_path)

# Print the extracted text
print(extracted_text)
# Out:
#
#
#
# B.Tech in Computer Science and Engineering
#
# 2024-25 Batch
#
#
#
#
#
# SCHOOL OF ENGINEERING AND TECHNOLOGY
# CENTURION UNIVERSITY OF TECHNOLOGY & MANAGEMENT
# Odisha-761211, India
#
# Web Site: - www.cutm.ac.in
# COURSE STRUCTURE AND SYLLABI
# CENTURION UNIVERSITY OF TECHNOLOGY AND MANAGEMENT,
# ODISHA
#
#
#
#
#
#
#
#
# This is to certify that the syllabus of the Programme B.Tech in Computer Science
# and Engineering of the School of Engineering and Technology is approved in the
# 14th Academic Council Meeting held on 22nd November 2024.
#
#
#
#
#
# Dean
# School of Engineering and Technology,
# CUTM, Odisha
#
#
#
#
#
# CERTIFICATE
#
# Centurion University of Technology and Management
# Odisha
#
# B.Tech. in Computer Science and Engineering(CSE)
# CHOICE BASED CREDIT SYSTEM
#
# COURSE STRUCTURE & SYLLABUS
#
# BASKET – I, II, III, IV & V
#
#
#
#
#
#
#
#
#
# School of Engineering & Technology
# 2024
#
#
# Index
# Basket - I
#
# Course Code  Course Title     Page No
# ...
