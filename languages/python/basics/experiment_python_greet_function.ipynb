# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/languages/python/basics/experiment_python_greet_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet(name):
  """Greets the given name."""
  return f"Hello, {name}!"

# %%
# Demonstrate the greet function
message = greet("Prem")
print(message)
# Out:
# Hello, Prem!
