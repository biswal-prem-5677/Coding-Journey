# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/python/dsa/Python_Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Tuples**

# %% [markdown]
# A tuple in Python is an immutable ordered collection of elements.
#
#
# *   Tuples are similar to lists, but unlike lists, they cannot be changed after their creation (i.e., they are immutable).
# *   Tuples can hold elements of different data types.
#
# *   The main characteristics of tuples are being ordered, heterogeneous and immutable.
#
#
# # **Creating a Tuple**
#
# A tuple is created by placing all the items inside parentheses (), separated by commas. A tuple can have any number of items and they can be of different [data types](https://www.geeksforgeeks.org/python/python-data-types/).

# %%
tup = ()
print(tup)

# Using String
tup = ('Geeks', 'For')
print(tup)

# Using List
li = [1, 2, 4, 5, 6]
print(tuple(li))

# Using Built-in Function
tup = tuple('Geeks')
print(tup)
# Out:
# ()
# ('Geeks', 'For')
# (1, 2, 4, 5, 6)
# ('G', 'e', 'e', 'k', 's')

# %% [markdown]
# Creating a Tuple with Mixed Datatypes.
# Tuples can contain elements of various data types, including other tuples, lists, dictionaries and even [functions](https://www.geeksforgeeks.org/python/python-functions/).

# %%
tup = (5, 'Welcome', 7, 'Geeks')
print(tup)

# Creating a Tuple with nested tuples
tup1 = (0, 1, 2, 3)
tup2 = ('python', 'geek')
tup3 = (tup1, tup2)
print(tup3)

# Creating a Tuple with repetition
tup1 = ('Geeks',) * 3
print(tup1)

# Creating a Tuple with the use of loop
tup = ('Geeks')
n = 5
for i in range(int(n)):
    tup = (tup,)
    print(tup)
# Out:
# (5, 'Welcome', 7, 'Geeks')
# ((0, 1, 2, 3), ('python', 'geek'))
# ('Geeks', 'Geeks', 'Geeks')
# ('Geeks',)
# (('Geeks',),)
# ((('Geeks',),),)
# (((('Geeks',),),),)
# ((((('Geeks',),),),),)

# %%
tup = (5, 'Welcome', True, 5.89)
print(tup)
# Out:
# (5, 'Welcome', True, 5.89)

# %% [markdown]
# # **Python Tuple Basic Operations**
# Below are the Python tuple operations.
#
#
# 1.   Accessing of Python Tuples
#
# 1.   Concatenation of Tuples
# 2.   Slicing of Tuple
#
#
# 2.   Deleting a Tuple
#
#
#
#
#
#
#
# # **Accessing of Tuples**
# We can access the elements of a tuple by using indexing and [slicing](https://www.geeksforgeeks.org/python/tuple-slicing-python/), similar to how we access elements in a list. Indexing starts at 0 for the first element and goes up to n-1, where n is the number of elements in the tuple. Negative indexing starts from -1 for the last element and goes backward.

# %%
# Accessing Tuple with Indexing
tup = tuple("Geeks")
print(tup[0])

# Accessing a range of elements using slicing
print(tup[1:4])
print(tup[:3])

# Tuple unpacking
tup = ("Geeks", "For", "Geeks")

# This line unpack values of Tuple1
a, b, c = tup
print(a)
print(b)
print(c)
# Out:
# G
# ('e', 'e', 'k')
# ('G', 'e', 'e')
# Geeks
# For
# Geeks

# %%
tup = (5, 'Welcome', True, 5.89)
print(tup[0])
print(tup[1:3])
# Out:
# 5
# ('Welcome', True)

# %%
print(tup[-1])
print(tup[-3])
print(tup[-1:-2:-2])
# Out:
# 5.89
# Welcome
# (5.89,)

# %%
tup = (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
print(tup[3][2])
print(tup[3][1:4:2])
print(tup[1][3])
# Out:
# 2
# (1, 3)
# c

# %%
tup = (5, 'Welcome', True, [0, 1, 2, 3, 4], 5.89)
tup[3][2] = "Home"
print(tup)
# Out:
# (5, 'Welcome', True, [0, 1, 'Home', 3, 4], 5.89)

# %%
tup = (5, 'Welcome', True, [0, 1, 2, 3, 4], 5.89)
tup[1][2] = "AAA"
print(tup)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3560092323.py in <cell line: 0>()
#       1 tup = (5, 'Welcome', True, [0, 1, 2, 3, 4], 5.89)
# ----> 2 tup[1][2] = "AAA"
#       3 print(tup)
#
# TypeError: 'str' object does not support item assignment

# %%
tup = (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
tup[3][2] = "Home"
print(tup)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3703109159.py in <cell line: 0>()
#       1 tup = (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
# ----> 2 tup[3][2] = "Home"
#       3 print(tup)
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup = (5, 'Welcome', True, {0, 1, 2, 3, 4}, 5.89)
tup[3][2] = "Home"
print(tup)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1045752611.py in <cell line: 0>()
#       1 tup = (5, 'Welcome', True, {0, 1, 2, 3, 4}, 5.89)
# ----> 2 tup[3][2] = "Home"
#       3 print(tup)
#
# TypeError: 'set' object does not support item assignment

# %%
tup = (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
del tup[0]
print(tup)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3368731414.py in <cell line: 0>()
#       1 tup = (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
# ----> 2 del tup[0]
#       3 print(tup)
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
tup = (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
del tup
print(tup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3253611779.py in <cell line: 0>()
#       1 tup = (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
#       2 del tup
# ----> 3 print(tup)
#
# NameError: name 'tup' is not defined

# %%
tup = (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
print(tup[1:4])
# Out:
# ('Welcome', True, (0, 1, 2, 3, 4))

# %%
tup = (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
print(tup[1:4:2])
# Out:
# ('Welcome', (0, 1, 2, 3, 4))

# %%
tup = (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
print(tup[1][0:8:2])
print(tup[1][0:8:-2])
print(tup[1][::-1])
print(tup[1][::-2])
print(tup[3][::-1])
print(tup[3][::-2])
# Out:
# Wloe
#
# emocleW
# eolW
# (4, 3, 2, 1, 0)
# (4, 2, 0)

# %%
print(tup[::-1])
# Out:
# (5.89, (0, 1, 2, 3, 4), True, 'Welcome', 5)

# %%
print(tup[-1:-6:-1])
# Out:
# (5.89, (0, 1, 2, 3, 4), True, 'Welcome', 5)

# %%
tup = (22,33,44,55,66,77)
print(tup[::-1])
print(tup[-1:-6:-1])
print(tup[1:5])
# Out:
# (77, 66, 55, 44, 33, 22)
# (77, 66, 55, 44, 33)
# (33, 44, 55, 66)

# %% [markdown]
# # **Concatenation of Tuples**
# Tuples can be concatenated using the + operator. This operation combines two or more tuples to create a new tuple.
#
# Note: Only the same datatypes can be combined with concatenation, an error arises if a list and a tuple are combined.
#
# ![Screenshot 2025-12-22 145614.png](data:image/png;base64,...)

# %% [markdown]
# You can reverse a tuple by using slicing with a step of `-1`. This creates a new tuple with the elements in reverse order.

# %%
my_tuple = (1, 2, 3, 4, 5)
reversed_tuple = my_tuple[::-1]

print(f"Original tuple: {my_tuple}")
print(f"Reversed tuple: {reversed_tuple}")

# %%
tup1 = (0, 1, 2, 3)
tup2 = ('Geeks', 'For', 'Geeks')

tup3 = tup1 + tup2
print(tup3)
# Out:
# (0, 1, 2, 3, 'Geeks', 'For', 'Geeks')

# %% [markdown]
# # **Slicing of Tuple**
# Slicing a tuple means creating a new tuple from a subset of elements of the original tuple. The slicing syntax is tuple[start:stop:step].
#
# Note- Negative Increment values can also be used to reverse the sequence of Tuples.
#
# ![Screenshot 2025-12-22 145614.png](data:image/png;base64,...)

# %%
tup = tuple('GEEKSFORGEEKS')

# Removing First element
print(tup[1:])

# Reversing the Tuple
print(tup[::-1])

# Printing elements of a Range
print(tup[4:9])
# Out:
# ('E', 'E', 'K', 'S', 'F', 'O', 'R', 'G', 'E', 'E', 'K', 'S')
# ('S', 'K', 'E', 'E', 'G', 'R', 'O', 'F', 'S', 'K', 'E', 'E', 'G')
# ('S', 'F', 'O', 'R', 'G')

# %% [markdown]
# # **Deleting a Tuple**
# Since tuples are immutable, we cannot delete individual elements of a tuple. However, we can delete an entire tuple using [del statement](https://www.geeksforgeeks.org/python/python-del-to-delete-objects/).
#
# Note: Printing of Tuple after deletion results in an Error.

# %%
tup = (0, 1, 2, 3, 4)
del tup

print(tup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1483046308.py in <cell line: 0>()
#       2 del tup
#       3
# ----> 4 print(tup)
#
# NameError: name 'tup' is not defined

# %% [markdown]
# # Tuple Unpacking with Asterisk (*) **bold text**
# In Python, the " * " operator can be used in tuple unpacking to grab multiple items into a list. This is useful when you want to extract just a few specific elements and collect the rest together.

# %%
tup = (1, 2, 3, 4, 5)

a, *b, c = tup

print(a)
print(b)
print(c)
# Out:
# 1
# [2, 3, 4]
# 5

# %% [markdown]
# Explanation:
#
# a gets the first item.
#
# c gets the last item.
#
# *b collects everything in between into a list.

# %% [markdown]
# # [**Tuple Problems And Quizs**](https://www.geeksforgeeks.org/python/python-tuples/)

# %% [markdown]
# # **Membership Test in Tuple**

# %%
tup = (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
print(5 in tup)
print('Welcome' not in tup)
print(0 in tup)
# Out:
# True
# False
# False

# %%
tup = (22,33,44,55,66,77)
print(44 in tup)
print(88 not in tup)
print(99 in tup)
print((22,33) in tup)
# Out:
# True
# True
# False
# False

# %% [markdown]
# # **Iterating a Tuple**

# %%
tup = (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
for item in tup:
    print(item)
# Out:
# 5
# Welcome
# True
# (0, 1, 2, 3, 4)
# 5.89

# %%
for item in tup:
    print(tup)
# Out:
# (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
# (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
# (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
# (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
# (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)

# %% [markdown]
# # **Tuple Methods**

# %%
tup = (5, 'Welcome', True, (0, 1, 2, 3, 4), 5.89)
print(tup.count(5))
print(tup.index('Welcome'))
print(tup.index(True))
# Out:
# 1
# 1
# 2

# %% [markdown]
# Create a tuple → Access elements using slicing → Apply tuple methods

# %%
# Step 1: Create a tuple
my_tuple = (10, 20, 30, 40, 50, 20)

# Step 2: Display original tuple
print("Original Tuple:", my_tuple)

# Step 3: Access elements using slicing
print("First 3 elements:", my_tuple[0:3])
print("Middle elements:", my_tuple[2:5])
print("Last 2 elements:", my_tuple[-2:])
print("Alternate elements:", my_tuple[::2])

# Step 4: Apply tuple methods

# Count occurrences of an element
count_20 = my_tuple.count(20)
print("Count of 20:", count_20)

# Find index of an element
index_30 = my_tuple.index(30)
print("Index of 30:", index_30)
# Out:
# Original Tuple: (10, 20, 30, 40, 50, 20)
# First 3 elements: (10, 20, 30)
# Middle elements: (30, 40, 50)
# Last 2 elements: (50, 20)
# Alternate elements: (10, 30, 50)
# Count of 20: 2
# Index of 30: 2
