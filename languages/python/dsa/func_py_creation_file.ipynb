# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/python/dsa/func_py_creation_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%writefile /content/drive/MyDrive/Colab_Notebooks/Python_And_AIML/Functions/math_utils.py

def add(a, b):
    return a + b

def multiply(a, b):
    return a * b

def subtract(a, b):
    return a-b
# Out:
# Overwriting /content/drive/MyDrive/Colab_Notebooks/Python_And_AIML/Functions/math_utils.py
