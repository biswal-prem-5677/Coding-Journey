# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/python/libraries/Pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/Social_Network_Ads[1].csv")
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.tail()
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
print(df.shape)
#**shape:** Returns dimensions of the DataFrame.
# Out:
# (400, 5)

# %%
print(df.size)
#**size:** gives the total number of elements in the DataFrame
# Out:
# 2000

# %%
df.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
df.iloc[4:7]
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0

# %%
df.loc[4:7, : ]
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1

# %%
d=df.drop(3,axis=0)
d
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 4    15804002    Male   19            76000          0
# 5    15728773    Male   27            58000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [399 rows x 5 columns]

# %%
df['Age'].unique()
# Out:
# array([19, 35, 26, 27, 32, 25, 20, 18, 29, 47, 45, 46, 48, 49, 31, 21, 28,
#        33, 30, 23, 24, 22, 59, 34, 39, 38, 37, 42, 40, 36, 41, 58, 55, 52,
#        60, 56, 53, 50, 51, 57, 44, 43, 54])

# %%
df['User ID'].unique()
# Out:
# array([15624510, 15810944, 15668575, 15603246, 15804002, 15728773,
#        15598044, 15694829, 15600575, 15727311, 15570769, 15606274,
#        15746139, 15704987, 15628972, 15697686, 15733883, 15617482,
#        15704583, 15621083, 15649487, 15736760, 15714658, 15599081,
#        15705113, 15631159, 15792818, 15633531, 15744529, 15669656,
#        15581198, 15729054, 15573452, 15776733, 15724858, 15713144,
#        15690188, 15689425, 15671766, 15782806, 15764419, 15591915,
#        15772798, 15792008, 15715541, 15639277, 15798850, 15776348,
#        15727696, 15793813, 15694395, 15764195, 15744919, 15671655,
#        15654901, 15649136, 15775562, 15807481, 15642885, 15789109,
#        15814004, 15673619, 15595135, 15583681, 15605000, 15718071,
#        15679760, 15654574, 15577178, 15595324, 15756932, 15726358,
#        15595228, 15782530, 15592877, 15651983, 15746737, 15774179,
#        15667265, 15655123, 15595917, 15668385, 15709476, 15711218,
# ...

# %%
#**iloc[]:** Integer-location based indexing.
print(df.iloc[0:2,  :])
# Out:
#     User ID Gender  Age  EstimatedSalary  Purchased
# 0  15624510   Male   19            19000          0
# 1  15810944   Male   35            20000          0

# %%
df.loc[9]
#**loc[]:** Label-based indexing.
# Out:
# User ID            15727311
# Gender               Female
# Age                      35
# EstimatedSalary       65000
# Purchased                 0
# Name: 9, dtype: object

# %%
df.loc[99]
# Out:
# User ID            15756820
# Gender               Female
# Age                      28
# EstimatedSalary       37000
# Purchased                 0
# Name: 99, dtype: object

# %%
# single column
df[['User ID']]

#extract a particular column from a DataFrame
# Out:
#       User ID
# 0    15624510
# 1    15810944
# 2    15668575
# 3    15603246
# 4    15804002
# ..        ...
# 395  15691863
# 396  15706071
# 397  15654296
# 398  15755018
# 399  15594041
#
# [400 rows x 1 columns]

# %%
df[['Purchased']]
#extract a particular column from a DataFrame
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [400 rows x 1 columns]

# %%
## multiple column
df[['User ID', 'Purchased',"Age"]]
# Out:
#       User ID  Purchased  Age
# 0    15624510          0   19
# 1    15810944          0   35
# 2    15668575          0   26
# 3    15603246          0   27
# 4    15804002          0   19
# ..        ...        ...  ...
# 395  15691863          1   46
# 396  15706071          1   51
# 397  15654296          1   50
# 398  15755018          0   36
# 399  15594041          1   49
#
# [400 rows x 3 columns]

# %%
df['Age'].value_counts()
#**value_counts():** Count unique values in a Series.
# Out:
# Age
# 35    32
# 37    20
# 26    16
# 41    16
# 42    16
# 39    15
# 40    15
# 48    14
# 47    14
# 27    13
# 38    13
# 28    12
# 36    12
# 46    12
# 31    11
# 30    11
# 49    10
# 29    10
# 33     9
# 32     9
# 24     9
# 59     7
# 19     7
# 45     7
# 20     7
# 60     7
# 34     6
# 23     6
# 52     6
# 25     6
# 58     6
# 53     5
# 57     5
# 22     5
# 18     5
# 21     4
# 50     4
# 54     4
# 55     3
# 56     3
# 51     3
# 43     3
# 44     2
# Name: count, dtype: int64

# %%
#**max() and min():** Find the maximum and minimum values in each column.

print(df.max())
# Out:
# User ID            15815236
# Gender                 Male
# Age                      60
# EstimatedSalary      150000
# Purchased                 1
# dtype: object

# %%
print(df.min())
# Out:
# User ID            15566689
# Gender               Female
# Age                      18
# EstimatedSalary       15000
# Purchased                 0
# dtype: object

# %%
df['x1'] = df['EstimatedSalary'] % 2
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased  x1
# 0    15624510    Male   19            19000          0   0
# 1    15810944    Male   35            20000          0   0
# 2    15668575  Female   26            43000          0   0
# 3    15603246  Female   27            57000          0   0
# 4    15804002    Male   19            76000          0   0
# ..        ...     ...  ...              ...        ...  ..
# 395  15691863  Female   46            41000          1   0
# 396  15706071    Male   51            23000          1   0
# 397  15654296  Female   50            20000          1   0
# 398  15755018    Male   36            33000          0   0
# 399  15594041  Female   49            36000          1   0
#
# [400 rows x 6 columns]

# %%
df_new = df.drop('Age',axis=1)
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased  x1
# 0    15624510    Male   19            19000          0   0
# 1    15810944    Male   35            20000          0   0
# 2    15668575  Female   26            43000          0   0
# 3    15603246  Female   27            57000          0   0
# 4    15804002    Male   19            76000          0   0
# ..        ...     ...  ...              ...        ...  ..
# 395  15691863  Female   46            41000          1   0
# 396  15706071    Male   51            23000          1   0
# 397  15654296  Female   50            20000          1   0
# 398  15755018    Male   36            33000          0   0
# 399  15594041  Female   49            36000          1   0
#
# [400 rows x 6 columns]
