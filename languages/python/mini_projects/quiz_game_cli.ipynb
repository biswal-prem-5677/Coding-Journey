# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/languages/python/mini_projects/quiz_game_cli.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Question bank
questions = [
    {
        "question": "What is the capital of India?",
        "options": ["A. Mumbai", "B. Delhi", "C. Kolkata", "D. Chennai"],
        "answer": "B"
    },
    {
        "question": "Which language is used for AI?",
        "options": ["A. Python", "B. HTML", "C. CSS", "D. SQL"],
        "answer": "A"
    },
    {
        "question": "What is 5 * 6?",
        "options": ["A. 11", "B. 25", "C. 30", "D. 60"],
        "answer": "C"
    },
    {
        "question": "Who developed Python?",
        "options": ["A. Elon Musk", "B. Dennis Ritchie", "C. Guido van Rossum", "D. Mark Zuckerberg"],
        "answer": "C"
    }
]

# Shuffle questions
random.shuffle(questions)

score = 0

print("\n🎮 Welcome to the Quiz Game!\n")

for i, q in enumerate(questions, 1):
    print(f"Q{i}: {q['question']}")

    for option in q["options"]:
        print(option)

    user_answer = input("Your answer (A/B/C/D): ").upper()

    if user_answer == q["answer"]:
        print("✅ Correct!\n")
        score += 1
    else:
        print(f"❌ Wrong! Correct answer: {q['answer']}\n")

# Final result
print("🎯 Game Over!")
print(f"Your Score: {score}/{len(questions)}")

# Performance message
if score == len(questions):
    print("🔥 Excellent!")
elif score >= len(questions) // 2:
    print("👍 Good job!")
else:
    print("💡 Keep practicing!")
# Out:
# 🎮 Welcome to the Quiz Game!
#
# Q1: Who developed Python?
# A. Elon Musk
# B. Dennis Ritchie
# C. Guido van Rossum
# D. Mark Zuckerberg
# Your answer (A/B/C/D): b
# ❌ Wrong! Correct answer: C
#
# Q2: Which language is used for AI?
# A. Python
# B. HTML
# C. CSS
# D. SQL
# Your answer (A/B/C/D): a
# ✅ Correct!
#
# Q3: What is 5 * 6?
# A. 11
# B. 25
# C. 30
# D. 60
# Your answer (A/B/C/D): 30
# ❌ Wrong! Correct answer: C
#
# Q4: What is the capital of India?
# A. Mumbai
# B. Delhi
# C. Kolkata
# D. Chennai
# Your answer (A/B/C/D): b
# ✅ Correct!
#
# 🎯 Game Over!
# Your Score: 2/4
# 👍 Good job!
