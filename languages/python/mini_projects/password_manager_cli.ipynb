# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/languages/python/mini_projects/password_manager_cli.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

def check_password_strength(password):
    score = 0

    if len(password) >= 8:
        score += 1
    if re.search(r"[A-Z]", password):
        score += 1
    if re.search(r"[a-z]", password):
        score += 1
    if re.search(r"[0-9]", password):
        score += 1
    if re.search(r"[!@#$%^&*(),.?\":{}|<>]", password):
        score += 1

    if score == 5:
        return "Very Strong"
    elif score >= 3:
        return "Moderate"
    else:
        return "Weak"



password = input("Enter password: ")
print("Strength:", check_password_strength(password))
# Out:
# Enter password: asdfgh12345
# Strength: Moderate

# %%
import json
import getpass

file = "passwords.json"

try:
    with open(file) as f:
        passwords = json.load(f)
except:
    passwords = {}

master = "admin123"

entered = getpass.getpass("Enter master password: ")

if entered != master:
    print("Access denied")
    exit()

while True:

    print("\n1 Add Password")
    print("2 View Passwords")
    print("3 Exit")

    choice = input("Choice: ")

    if choice == "1":

        site = input("Website: ")
        user = input("Username: ")
        pwd = getpass.getpass("Password: ")

        passwords[site] = {"user": user, "password": pwd}

        with open(file, "w") as f:
            json.dump(passwords, f)

    elif choice == "2":

        for site, info in passwords.items():

            print(site, info["user"], info["password"])

    else:
        break
# Out:
# Enter master password: ··········
# Access denied
#
# 1 Add Password
# 2 View Passwords
# 3 Exit
# Choice: 1
# Website: 147258
# Username: 147258
# Password: ··········
#
# 1 Add Password
# 2 View Passwords
# 3 Exit
# Choice: 3
