# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/languages/python/mini_projects/web_scraping/experiment_web_scraping_multithreaded_requests_beautifulsoup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.ycombinator.com"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

titles = soup.find_all("span", class_="titleline")

for t in titles:
    print(t.text)
# Out:
# Global Warming Has Accelerated Significantly (researchgate.net)
# Workers who love 'synergizing paradigms' might be bad at their jobs (cornell.edu)
# Show HN: Moongate – Ultima Online server emulator in .NET 10 with Lua scripting (github.com/moongate-community)
# Payphone Go (walzr.com)
# CT Scans of Health Wearables (lumafield.com)
# Analytic Fog Rendering with Volumetric Primitives (matejlou.blog)
# LibreSprite – open-source pixel art editor (libresprite.github.io)
# US economy unexpectedly sheds 92,000 jobs in February (bbc.com)
# System76 on Age Verification Laws (system76.com)
# Open Camera is a FOSS Camera App for Android (opencamera.org.uk)
# GPT-5.4 (openai.com)
# 10% of Firefox crashes are caused by bitflips (mas.to)
# Hardening Firefox with Anthropic's Red Team (blog.mozilla.org)
# "I'm obviously taking a risk here by advertising emoji directly." (aresluna.org)
# Show HN: Interactive 3D globe of EU shipping emissions (seafloor.pages.dev)
# ...

# %%
import requests
from bs4 import BeautifulSoup
import threading

urls = [
    "https://news.ycombinator.com",
    "https://quotes.toscrape.com",
]

def scrape(url):

    print("Scraping:", url)

    response = requests.get(url)

    soup = BeautifulSoup(response.text, "html.parser")

    titles = soup.find_all("a")

    for t in titles[:10]:
        print(t.text.strip())

threads = []

for url in urls:

    t = threading.Thread(target=scrape, args=(url,))
    t.start()
    threads.append(t)

for t in threads:
    t.join()
# Out:
# Scraping: https://news.ycombinator.com
# Scraping: https://quotes.toscrape.com
#
# Hacker News
# new
# past
# comments
# ask
# show
# jobs
# submit
# login
# Quotes to Scrape
# Login
# (about)
# change
# deep-thoughts
# thinking
# world
# (about)
# abilities
# choices
