# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/languages/python/mini_projects/experiment_random_text_generation_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

responses = [
    "AI will change the future.",
    "Innovation comes from curiosity.",
    "Technology empowers human creativity.",
    "Data is the new oil."
]

def generate_text():
    return random.choice(responses)

print(generate_text())
# Out:
# Innovation comes from curiosity.
