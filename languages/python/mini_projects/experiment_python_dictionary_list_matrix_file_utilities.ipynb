# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/languages/python/mini_projects/experiment_python_dictionary_list_matrix_file_utilities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def merge_dicts(dict1, dict2):
    return {**dict1, **dict2}

print(merge_dicts({"a": 1}, {"b": 2}))

# %%
def common_elements(list1, list2):
    return list(set(list1) & set(list2))

print(common_elements([1,2,3,4], [3,4,5,6]))
# Out:
# [3, 4]

# %%
def transpose(matrix):
    return list(map(list, zip(*matrix)))

matrix = [
    [1,2,3],
    [4,5,6]
]

print(transpose(matrix))
# Out:
# [[1, 4], [2, 5], [3, 6]]

# %%
import csv

def read_csv(file_name):
    with open(file_name, "r") as file:
        reader = csv.DictReader(file)

        for row in reader:
            print(row)

# %%
import json

def load_json(file_path):
    with open(file_path, "r") as file:
        return json.load(file)

# %%
import os

def file_size(path):
    return os.path.getsize(path)

print(file_size("data.csv"))
