# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/ai/02_machine_learning/supervised/regression/experiment_linear_regression_abstraction_numpy_pytorch_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Data
X = np.array([[1], [2], [3], [4]])
y = np.array([[2], [4], [6], [8]])

# Initialize weights
w = np.random.randn(1, 1)
b = np.zeros((1,))

lr = 0.01

# Training loop
for epoch in range(1000):
    # Forward pass
    y_pred = X @ w + b

    # Loss (MSE)
    loss = np.mean((y_pred - y) ** 2)

    # Gradients (manual)
    dw = (2/len(X)) * X.T @ (y_pred - y)
    db = (2/len(X)) * np.sum(y_pred - y)

    # Update
    w -= lr * dw
    b -= lr * db

print("Weight:", w, "Bias:", b)
# Out:
# Weight: [[1.99203989]] Bias: [0.02340369]

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Data
X = torch.tensor([[1.0], [2.0], [3.0], [4.0]])
y = torch.tensor([[2.0], [4.0], [6.0], [8.0]])

# Model
model = nn.Linear(1, 1)

# Loss & optimizer
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Training loop
for epoch in range(1000):
    # Forward
    y_pred = model(X)

    # Loss
    loss = criterion(y_pred, y)

    # Backward (AUTO gradients)
    optimizer.zero_grad()
    loss.backward()

    # Update
    optimizer.step()

print("Weight:", model.weight.item(), "Bias:", model.bias.item())
# Out:
# Weight: 1.998418927192688 Bias: 0.004648247733712196

# %%
import tensorflow as tf
from tensorflow import keras

# Data
X = tf.constant([[1], [2], [3], [4]], dtype=tf.float32)
y = tf.constant([[2], [4], [6], [8]], dtype=tf.float32)

# Model
model = keras.Sequential([
    keras.layers.Input(shape=(1,)), # Recommended way to define input shape
    keras.layers.Dense(1)
])

# Compile
model.compile(optimizer='sgd', loss='mse')

# Train
model.fit(X, y, epochs=1000, verbose=0)

# Weights
w, b = model.layers[0].get_weights()
print("Weight:", w, "Bias:", b)
# Out:
# Weight: [[1.9983522]] Bias: [0.00484505]
