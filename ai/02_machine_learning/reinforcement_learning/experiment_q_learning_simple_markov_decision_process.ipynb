# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/ai/02_machine_learning/reinforcement_learning/experiment_q_learning_simple_markov_decision_process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random

states = ['A', 'B']
actions = ['left', 'right']

P = {
    'A': {'left': ('A', 0), 'right': ('B', 1)},
    'B': {'left': ('A', 0), 'right': ('B', 2)}
}

# Q-table
Q = {(s, a): 0 for s in states for a in actions}

alpha = 0.1
gamma = 0.9
epsilon = 0.2

def choose_action(state):
    if random.uniform(0, 1) < epsilon:
        return random.choice(actions)
    else:
        return max(actions, key=lambda a: Q[(state, a)])

# Training
for episode in range(100):
    state = random.choice(states)

    for step in range(10):
        action = choose_action(state)
        next_state, reward = P[state][action]

        best_next = max(Q[(next_state, a)] for a in actions)

        Q[(state, action)] += alpha * (
            reward + gamma * best_next - Q[(state, action)]
        )

        state = next_state

# Print learned Q-values
print("Q-table:")
for k, v in Q.items():
    print(k, round(v, 2))
# Out:
# Q-table:
# ('A', 'left') 12.22
# ('A', 'right') 18.98
# ('B', 'left') 17.03
# ('B', 'right') 19.99
