# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/ai/02_machine_learning/unsupervised/dimensionality_reduction/experiment_pca_dimensionality_reduction_variance_analysis_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================
# LEVEL 1: BASIC PCA
# ============================================

import numpy as np
from sklearn.decomposition import PCA

# Create high-dimensional data
X = np.random.rand(100, 5)

# Reduce to 2 dimensions
pca = PCA(n_components=2)

X_reduced = pca.fit_transform(X)

print("Original shape:", X.shape)
print("Reduced shape:", X_reduced.shape)
# Out:
# Original shape: (100, 5)
# Reduced shape: (100, 2)

# %%
import matplotlib.pyplot as plt

plt.scatter(X_reduced[:,0], X_reduced[:,1])
plt.title("PCA Projection")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.show()

# %%
from sklearn.datasets import load_iris

data = load_iris()
X = data.data
y = data.target

pca = PCA(n_components=2)

X_pca = pca.fit_transform(X)

plt.scatter(X_pca[:,0], X_pca[:,1], c=y, cmap='viridis')
plt.title("Iris PCA")
plt.show()

# %%
pca = PCA()

pca.fit(X)

variance = pca.explained_variance_ratio_

print("Variance per component:", variance)
print("Total variance (first 2):", sum(variance[:2]))
# Out:
# Variance per component: [0.92461872 0.05306648 0.01710261 0.00521218]
# Total variance (first 2): 0.9776852063187977

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("pca", PCA(n_components=2)),
    ("model", LogisticRegression())
])

pipeline.fit(X, y)

preds = pipeline.predict(X)

print("Pipeline working ✅")
# Out:
# Pipeline working ✅
