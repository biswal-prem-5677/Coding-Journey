# %% [markdown]
# <a href="https://colab.research.google.com/github/biswal-prem-5677/Coding-Journey/blob/main/ai/03_deep_learning/neural_network_basics/experiment_perceptron_and_gate_decision_boundary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

class Perceptron:
  def __init__(self, learning_rate=0.1, epochs=20):
    self.learning_rate = learning_rate
    self.epochs = epochs
    self.weights = None
    self.bias = None

  # Step Activation Function
  def activation(self, x):
    return 1 if x>=0 else 0

  # Training Function
  def fit(self, X, y):
    n_samples, n_features = X.shape
    self.weights = np.zeros(n_features)
    self.bias = 0

    for _ in range(self.epochs):
      for i in range(n_samples):
        linear_output = np.dot(X[i], self.weights) + self.bias
        prediction = self.activation(linear_output)

        error = y[i] - prediction

        #Update rule
        self.weights += self.learning_rate * error * X[i]
        self.bias += self.learning_rate*error

  def predict(self, X):
    linear_output = np.dot(X, self.weights) + self.bias
    return np.array([self.activation(x) for x in linear_output])



# AND Logic Gate Dataset
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

y = np.array([0, 0, 0, 1])

#Train Model
model = Perceptron(learning_rate=0.1, epochs=10)
model.fit(X, y)

predictions = model.predict(X)

print("Weights:", model.weights)
print("Bias:", model.bias)
print("Predictions:", predictions)

# Visualization
plt.figure()

# Plot class 0
for i in range(len(X)):
  if y[i] == 0:
    plt.scatter(X[i][0], X[i][1])

# Plot class 1
for i in range(len(X)):
  if y[i] == 1:
    plt.scatter(X[i][0], X[i][1], marker = 'x')

# Plot decision boundary
x_values= np.linspace(-0.5, 1.5, 100)

#Avoid Decision by 0
if model.weights[1] != 0:
  y_values = -(model.weights[0]* x_values + model.bias) /model.weights[1]
  plt.plot(x_values, y_values)

  plt.xlabel('X1')
  plt.ylabel('X2')
  plt.title('AND Logic Gate')
  plt.show()
# Out:
# Weights: [0.2 0.1]
# Bias: -0.20000000000000004
# Predictions: [0 0 0 1]

# %%
import numpy as np
import matplotlib.pyplot as plt

class Perceptron:
  def __init__(self, learning_rate=0.3, epochs=20):
    self.learning_rate = learning_rate
    self.epochs = epochs
    self.weights = None
    self.bias = None

  # Step Activation Function
  def activation(self, x):
    return 1 if x>=0 else 0

  # Training Function
  def fit(self, X, y):
    n_samples, n_features = X.shape
    self.weights = np.zeros(n_features)
    self.bias = 0

    for _ in range(self.epochs):
      for i in range(n_samples):
        linear_output = np.dot(X[i], self.weights) + self.bias
        prediction = self.activation(linear_output)

        error = y[i] - prediction

        #Update rule
        self.weights += self.learning_rate * error * X[i]
        self.bias += self.learning_rate*error

  def predict(self, X):
    linear_output = np.dot(X, self.weights) + self.bias
    return np.array([self.activation(x) for x in linear_output])



# AND Logic Gate Dataset
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

y = np.array([0, 0, 0, 1])

#Train Model
model = Perceptron(learning_rate=0.3, epochs=10)
model.fit(X, y)

predictions = model.predict(X)

print("Weights:", model.weights)
print("Bias:", model.bias)
print("Predictions:", predictions)

# Visualization
plt.figure()

# Plot class 0
for i in range(len(X)):
  if y[i] == 0:
    plt.scatter(X[i][0], X[i][1])

# Plot class 1
for i in range(len(X)):
  if y[i] == 1:
    plt.scatter(X[i][0], X[i][1], marker = 'x')

# Plot decision boundary
x_values= np.linspace(-0.5, 1.5, 100)

#Avoid Decision by 0
if model.weights[1] != 0:
  y_values = -(model.weights[0]* x_values + model.bias) /model.weights[1]
  plt.plot(x_values, y_values)

  plt.xlabel('X1')
  plt.ylabel('X2')
  plt.title('AND Logic Gate')
  plt.show()
# Out:
# Weights: [0.6 0.3]
# Bias: -0.8999999999999999
# Predictions: [0 0 0 1]

# %%
# Implementation of single layer perceptron
